# %%
import numpy as np
import seaborn as sns
sns.set(style="ticks")

rs = np.random.RandomState(100)
x = rs.gamma(2, size=4000)
y = -.5 * x + rs.normal(size=4000)

jp = sns.jointplot(x, y, kind="hex", color="#BCB341")
